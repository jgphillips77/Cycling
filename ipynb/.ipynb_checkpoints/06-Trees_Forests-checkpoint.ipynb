# %%
cd ..
# Out:
# /Users/johnphillips/Desktop/DSI/Cycling

# %%
# %matplotlib inline

# %%
# %run __init__.py

# %%
# Import pickled clean data:
lap1 = pd.read_pickle('data/lap1.p')
lap2 = pd.read_pickle('data/lap2.p')
lap3 = pd.read_pickle('data/lap3.p')

# %%
# Concatenate all three laps for better modeling

data = pd.concat([lap1, lap2, lap3], axis=0)

# %%
data.head()
# Out:
#               distance   latitude  longitude  altitude  power  cadence  speed  \
# elapsed_time
# 2                  0.0  36.985600  136.79163        41  462.0     32.0   0.00
# 3                  0.0  36.985603  136.79161        41  462.0     32.0   0.00
# 4                  3.0  36.985607  136.79160        41  462.0     32.0   0.01
# 5                  3.0  36.985622  136.79156        41  462.0     32.0   4.09
# 6                  7.0  36.985695  136.79149        41  462.0     32.0   5.56
#
#               ankling_log_left  ankling_log_right  foot_range_log_left  \
# elapsed_time
# 2                          0.0                0.0                 45.9
# 3                          0.0                0.0                 45.9
# 4                          0.0                0.0                 45.9
# 5                          0.0                0.0                 45.9
# 6                          0.0                0.0                 45.9
#
#               foot_range_log_right  pedaling_delay_log_left  \
# elapsed_time
# 2                             53.7                      7.2
# 3                             53.7                      7.2
# 4                             53.7                      7.2
# 5                             53.7                      7.2
# 6                             53.7                      7.2
#
#               pedaling_delay_log_right  waist_angle_log_center  \
# elapsed_time
# 2                                  7.5                    57.9
# 3                                  7.5                    52.1
# 4                                  7.5                    49.3
# 5                                  7.5                    54.7
# 6                                  7.5                    54.4
#
#               waist_d_rot_y_center  waist_d_rot_z_center  \
# elapsed_time
# 2                              3.2                   0.7
# 3                              6.8                   2.0
# 4                              4.6                   2.7
# 5                              8.3                   4.6
# 6                             24.1                   7.6
#
#               torso_angle_log_center  torso_d_rot_y_center  \
# elapsed_time
# 2                               28.0                   2.0
# 3                               19.8                   1.4
# 4                               18.2                   1.0
# 5                               20.9                   4.4
# 6                               21.2                   4.1
#
#               torso_d_rot_z_center
# elapsed_time
# 2                              2.2
# 3                              1.7
# 4                              2.7
# 5                             10.1
# 6                             14.4

# %%
data.tail()
# Out:
#               distance   latitude  longitude  altitude  power  cadence  speed  \
# elapsed_time
# 3218           38408.0  36.985200  136.79156        47  348.0     89.0  13.01
# 3219           38422.0  36.985330  136.79153        47  392.0     88.0  12.87
# 3220           38435.0  36.985443  136.79150        47  355.0     88.0  12.89
# 3221           38447.0  36.985558  136.79147        47   50.0     84.0  12.72
# 3222           38462.0  36.985660  136.79144        47    0.0      0.0  12.35
#
#               ankling_log_left  ankling_log_right  foot_range_log_left  \
# elapsed_time
# 3218                       6.3                0.0                 41.8
# 3219                       0.0                0.0                 47.0
# 3220                       0.0               12.4                 47.0
# 3221                       0.0               12.4                 47.0
# 3222                       0.0               12.4                 47.0
#
#               foot_range_log_right  pedaling_delay_log_left  \
# elapsed_time
# 3218                          53.4                     14.4
# 3219                          53.4                     10.8
# 3220                          53.4                     23.7
# 3221                          53.4                     23.7
# 3222                          53.4                     23.7
#
#               pedaling_delay_log_right  waist_angle_log_center  \
# elapsed_time
# 3218                               1.4                    48.5
# 3219                               1.5                    47.4
# 3220                              13.6                    48.0
# 3221                              13.6                    44.0
# 3222                              13.6                    47.2
#
#               waist_d_rot_y_center  waist_d_rot_z_center  \
# elapsed_time
# 3218                           6.0                   6.0
# 3219                           9.0                   5.2
# 3220                           6.9                   5.5
# 3221                           4.7                   6.3
# 3222                           4.4                   7.3
#
#               torso_angle_log_center  torso_d_rot_y_center  \
# elapsed_time
# 3218                            13.2                   9.8
# 3219                             9.0                   9.8
# 3220                            15.2                   7.8
# 3221                            16.2                   8.9
# 3222                            15.3                   5.8
#
#               torso_d_rot_z_center
# elapsed_time
# 3218                          11.2
# 3219                          10.0
# 3220                          10.3
# 3221                          10.5
# 3222                           6.1

# %%
# Standard plot to inspect the join.
plt.figure(figsize=(8, 8))
data.power.plot()
data.altitude.plot()
data.cadence.plot()
data.speed.plot()
plt.show()

# %%
# Let's do a model focused on power.
X = data.drop(['power'], axis=1) 

# Make a y based upon Power
y = data['power']

# %%
# Standard split:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state = 42)

# %% [markdown]
# ## Tree Modeling

# %% [markdown]
# We know from the Benchmark that our Decision Tree Regressor was overfitting on the test data.  Let's fix that!

# %%
# Basic decision tree regression model
dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)

# Check the score on train and test
print(dt.score(X_train, y_train))
print(dt.score(X_test, y_test))
# Out:
# 1.0
# 0.5587219112292046

# %%
# Loop through a few different max depths and check the performance
for d in [3, 5, 10, 15, 20]:
    dt = DecisionTreeRegressor(max_depth=d)
    dt.fit(X_train, y_train)

    # Print out the scores on train and test
    print('max_depth=', str(d))
    print(dt.score(X_train, y_train))
    print(dt.score(X_test, y_test))
    print("--------")
# Out:
# ('max_depth=', '3')
# 0.6571682682519234
# 0.5763376684543291
# --------
# ('max_depth=', '5')
# 0.7779718593357478
# 0.64194341776902
# --------
# ('max_depth=', '10')
# 0.9221675598543903
# 0.6388747728756965
# --------
# ('max_depth=', '15')
# 0.9805104514983382
# 0.6027748902393075
# --------
# ('max_depth=', '20')
# 0.9969732449651985
# 0.5568409175926122
# --------

# %%
# Use the best max_depth of 5 from last model to fit a decision tree
dt = DecisionTreeRegressor(max_depth=5)
dt.fit(X_train, y_train)

# Make Predictions
train_predictions = dt.predict(X_train)
test_predictions = dt.predict(X_test)

# Predictions vs Actual Values
plt.figure(figsize=(8, 8))
plt.scatter(train_predictions, y_train, label='train', alpha=0.4, c='r') # Red is Train Data
plt.scatter(test_predictions, y_test, label='test', alpha=0.3,) # Blue is Test Data
plt.show()

# %% [markdown]
# ## Random Forests

# %% [markdown]
# Can we improve our Decision Tree with a Forest?

# %%
# Create the random forest model and fit to the training data
rfr = RandomForestRegressor(n_estimators=200)
rfr.fit(X_train, y_train)

# Look at the R^2 scores on train and test
print(rfr.score(X_train, y_train))
print(rfr.score(X_test, y_test))
# Out:
# 0.9759849963238005
# 0.7921057536522735

# %%
# Which hyperparameters score best?
# Create a dictionary to search
grid = {'n_estimators':[200], 'max_depth': [3, 5], 'max_features': [4, 8, 12], 'random_state': [42]}
test_scores = []

# Loop through the parameter grid, set the hyperparameters, and save the scores
for g in ParameterGrid(grid):
    rfr.set_params(**g)  # ** is "unpacking" the dictionary
    rfr.fit(X_train, y_train)
    test_scores.append(rfr.score(X_test, y_test))

# Find best hyperparameters
best_idx = np.argmax(test_scores)
print(test_scores[best_idx], ParameterGrid(grid)[best_idx])
# Out:
# (0.7047796857943143, {'n_estimators': 200, 'max_features': 12, 'random_state': 42, 'max_depth': 5})

# %%
# Use the best hyperparameters from before to fit a random forest model
rfr = RandomForestRegressor(n_estimators=200, max_depth=5, max_features=12, random_state=42)
rfr.fit(X_train, y_train)

# Make predictions with our model
train_predictions = rfr.predict(X_train)
test_predictions = rfr.predict(X_test)

# Create a scatter plot with train and test actual vs predictions
plt.figure(figsize=(8, 8))
plt.scatter(y_train, train_predictions, label='train', alpha=0.4) # Train data is blue
plt.scatter(y_test, test_predictions, label='test', alpha=0.3) # Test data is Orange
plt.legend()
plt.show()

# %%
# Get feature importances from our random forest model
importances = rfr.feature_importances_
feature_names = X.columns

# Get the index of importances from greatest importance to least
sorted_index = np.argsort(importances)[::-1]
x = range(len(importances))

# Create tick labels 
labels = np.array(feature_names)[sorted_index]
plt.figure(figsize=(8, 8))
plt.bar(x, importances[sorted_index], tick_label=labels)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## What about Boosting?

# %%
# Create Gradient Boost Model
gbr = GradientBoostingRegressor(max_features=12,
                                learning_rate=0.02,
                                n_estimators=200,
                                subsample=0.6,
                                random_state=42)
gbr.fit(X_train, y_train)

print(gbr.score(X_train, y_train))
print(gbr.score(X_test, y_test))
# Out:
# 0.8372328322407624
# 0.7376818963664806

# %%
# Extract feature importances from the fitted gradient boosting model
feature_importances = gbr.feature_importances_
features = X.columns

# Get the indices of the largest to smallest feature importances
sorted_index = np.argsort(feature_importances)[::-1]
x = range(features.shape[0])

# Create tick labels 
labels = np.array(feature_names)[sorted_index]
plt.figure(figsize=(8, 8))
plt.bar(x, feature_importances[sorted_index], tick_label=labels)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Let's try XG Boost

# %%
#!pip install xgboost

# %%
from xgboost import XGBRegressor

model = XGBRegressor()

# Add silent=True to avoid printing out updates with each cycle
model.fit(X_train, y_train, verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
# make predictions
predictions = model.predict(X_test)

from sklearn.metrics import mean_absolute_error
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, y_test)))
# Out:
# Mean Absolute Error : 27.30293739581293

# %%
model = XGBRegressor(n_estimators=1000)
model.fit(X_train, y_train, early_stopping_rounds=5, 
             eval_set=[(X_test, y_test)], verbose=False)
predictions = model.predict(X_test)
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, y_test)))
# Out:
# Mean Absolute Error : 26.248290907782177

# %%
model = XGBRegressor(n_estimators=1000, learning_rate=0.05)
model.fit(X_train, y_train, early_stopping_rounds=5, 
             eval_set=[(X_test, y_test)], verbose=False)
predictions = model.predict(X_test)
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, y_test)))
# Out:
# Mean Absolute Error : 26.493848736757457

# %%
# Which hyperparameters score best?
# Create a dictionary to search
grid = {'n_estimators':[250, 500, 1000], 'learning_rate': [0.05, 0.1, 0.5], 'max_depth': [3, 5, 10]}
test_scores = []

model = XGBRegressor(random_state=42, early_stopping_rounds=5)

# Loop through the parameter grid, set the hyperparameters, and save the scores
for g in ParameterGrid(grid):
    model.set_params(**g)  # ** is "unpacking" the dictionary
    model.fit(X_train, y_train)
    test_scores.append(model.score(X_test, y_test))

# Find best hyperparameters
best_idx = np.argmax(test_scores)
print(test_scores[best_idx], ParameterGrid(grid)[best_idx])
# Out:
# (0.8164445739803183, {'n_estimators': 250, 'learning_rate': 0.1, 'max_depth': 5})

# %%
final_model = XGBRegressor(n_estimators=250, learning_rate=0.1, random_state=42, early_stopping_rounds=5, max_depth=5)
final_model.fit(X_train, y_train, eval_set=[(X_test, y_test)], verbose=False)
predictions = final_model.predict(X_test)
print("Mean Absolute Error : " + str(mean_absolute_error(predictions, y_test)))
# Out:
# Mean Absolute Error : 24.842650548709454

# %% [markdown]
# ## Partial Dependence Plots
# Let's look at Partial Dependence of some top features

# %%
from sklearn.ensemble.partial_dependence import partial_dependence, plot_partial_dependence
from sklearn.preprocessing import Imputer

# %%
gbr = GradientBoostingRegressor(learning_rate=0.02,
                                n_estimators=200,
                                subsample=0.6,
                                random_state=42)

# Start with top 3 most important Features
cols_to_use = ['cadence', 'speed', 'torso_d_rot_z_center']
dataX = data[cols_to_use]
# Make a y based upon Power
y = data['power']

my_imputer = Imputer()
imputed_X = my_imputer.fit_transform(dataX)

gbr.fit(imputed_X, y)

bike_plots = plot_partial_dependence(gbr, features=[0,1,2], X=imputed_X, 
                                        feature_names=cols_to_use, grid_resolution=8)

# %%
# Next group of 3 Features
cols_to_use = ['waist_angle_log_center', 'foot_range_log_left', 'ankling_log_left']
dataX = data[cols_to_use]
# Make a y based upon Power
y = data['power']

my_imputer = Imputer()
imputed_X = my_imputer.fit_transform(dataX)

gbr.fit(imputed_X, y)

bike_plots = plot_partial_dependence(gbr, features=[0,1,2], X=imputed_X, 
                                        feature_names=cols_to_use, grid_resolution=8)
