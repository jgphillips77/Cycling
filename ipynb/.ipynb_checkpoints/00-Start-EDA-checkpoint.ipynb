# %% [markdown]
# ![Mario](https://cdn-cyclingtips.pressidium.com/wp-content/uploads/2016/02/Header-C-Mario.jpg "Upgrade your TT position!")

# %% [markdown]
# ## EDA on Time Trial National Championship data

# %%
cd ..
# Out:
# /Users/johnphillips/Desktop/DSI/Cycling

# %%
# %matplotlib inline

# %%
# %run __init__.py

# %% [markdown]
# Let's start with loading these files using Pandas and explore the data.

# %%
lap1 = pd.read_csv('data/saita_natTT_lap1.csv', delimiter=',')
lap1.describe()
# Out:
#        elapsed_time      distance     latitude    longitude     altitude  \
# count   1089.000000   1084.000000  1029.000000  1029.000000  1089.000000
# mean     546.000000   6334.341328    36.972665   136.786747    56.335170
# std      314.511526   3645.353290     0.013729     0.004625     9.786539
# min        2.000000      0.000000    36.953403   136.774750    41.000000
# 25%      274.000000   3300.750000    36.958946   136.783370    47.000000
# 50%      546.000000   6242.500000    36.970646   136.787870    56.000000
# 75%      818.000000   9398.000000    36.984734   136.790560    65.000000
# max     1090.000000  12820.000000    36.998150   136.793520    73.000000
#
#        l_r_balance        power      cadence        speed  heartrate  \
# count          0.0  1085.000000  1085.000000  1089.000000        0.0
# mean           NaN   317.294009    90.710599    11.788586        NaN
# std            NaN    78.066683    14.369887     2.288189        NaN
# min            NaN     0.000000     0.000000     0.000000        NaN
# 25%            NaN   296.000000    89.000000    10.850000        NaN
# 50%            NaN   326.000000    94.000000    12.270000        NaN
# 75%            NaN   354.000000    97.000000    12.900000        NaN
# max            NaN   606.000000   110.000000    17.520000        NaN
#
#                ...           leg_range_log_left  leg_range_log_right  \
# count          ...                          0.0                  0.0
# mean           ...                          NaN                  NaN
# std            ...                          NaN                  NaN
# min            ...                          NaN                  NaN
# 25%            ...                          NaN                  NaN
# 50%            ...                          NaN                  NaN
# 75%            ...                          NaN                  NaN
# max            ...                          NaN                  NaN
#
#        pedaling_delay_log_left  pedaling_delay_log_right  \
# count              1053.000000               1052.000000
# mean                 26.319943                 26.667110
# std                  10.833275                 12.244778
# min                   0.000000                  0.000000
# 25%                  19.300000                 19.275000
# 50%                  28.500000                 29.700000
# 75%                  33.800000                 35.300000
# max                  48.700000                 51.200000
#
#        waist_angle_log_center  waist_d_rot_y_center  waist_d_rot_z_center  \
# count             1089.000000           1089.000000           1089.000000
# mean                47.528099              7.521579              6.352617
# std                  2.794049              3.895105              2.023782
# min                 40.800000              0.800000              0.600000
# 25%                 46.100000              5.900000              5.300000
# 50%                 47.000000              7.000000              6.200000
# 75%                 48.600000              8.000000              7.300000
# max                 66.100000             30.600000             13.900000
#
#        torso_angle_log_center  torso_d_rot_y_center  torso_d_rot_z_center
# count             1089.000000           1089.000000           1089.000000
# mean                12.239853              5.769054              6.750964
# std                  4.152572              2.154695              1.788248
# min                  5.000000              1.000000              0.400000
# 25%                  9.900000              4.000000              5.800000
# 50%                 11.200000              5.700000              6.700000
# 75%                 13.000000              7.300000              7.600000
# max                 36.800000             11.500000             14.400000
#
# [8 rows x 24 columns]

# %%
lap2 = pd.read_csv('data/saita_natTT_lap2.csv', delimiter=',')
lap2.describe()
# Out:
#        elapsed_time      distance     latitude    longitude     altitude  \
# count   1071.000000   1070.000000  1027.000000  1027.000000  1071.000000
# mean    1624.000000  19139.999065    36.972722   136.786701    55.916900
# std      309.315373   3621.148621     0.013794     0.004601    10.789472
# min     1089.000000  12811.000000    36.953410   136.774720    43.000000
# 25%     1356.500000  16131.250000    36.958913   136.783365    46.000000
# 50%     1624.000000  19051.000000    36.970560   136.787750    54.000000
# 75%     1891.500000  22164.250000    36.984802   136.790430    66.000000
# max     2159.000000  25616.000000    36.998150   136.793500    74.000000
#
#        l_r_balance        power      cadence        speed  heartrate  \
# count          0.0  1071.000000  1071.000000  1071.000000        0.0
# mean           NaN   319.320261    89.368814    11.967600        NaN
# std            NaN    80.955446    13.516737     2.167798        NaN
# min            NaN     0.000000     0.000000     5.950000        NaN
# 25%            NaN   294.000000    89.000000    11.065000        NaN
# 50%            NaN   324.000000    92.000000    12.410000        NaN
# 75%            NaN   359.500000    94.000000    13.070000        NaN
# max            NaN   515.000000   113.000000    17.360000        NaN
#
#                ...           leg_range_log_left  leg_range_log_right  \
# count          ...                          0.0                  0.0
# mean           ...                          NaN                  NaN
# std            ...                          NaN                  NaN
# min            ...                          NaN                  NaN
# 25%            ...                          NaN                  NaN
# 50%            ...                          NaN                  NaN
# 75%            ...                          NaN                  NaN
# max            ...                          NaN                  NaN
#
#        pedaling_delay_log_left  pedaling_delay_log_right  \
# count              1042.000000               1038.000000
# mean                 26.557869                 26.459056
# std                  10.862203                 12.456695
# min                   0.000000                  0.000000
# 25%                  20.250000                 17.525000
# 50%                  28.500000                 29.500000
# 75%                  34.100000                 35.300000
# max                  49.600000                 49.900000
#
#        waist_angle_log_center  waist_d_rot_y_center  waist_d_rot_z_center  \
# count             1071.000000           1071.000000           1071.000000
# mean                48.865733              7.470401              6.339683
# std                  3.053390              3.685028              1.757867
# min                 42.300000              0.900000              0.800000
# 25%                 47.300000              6.000000              5.500000
# 50%                 48.400000              7.000000              6.300000
# 75%                 49.700000              7.900000              7.100000
# max                 63.600000             30.500000             13.200000
#
#        torso_angle_log_center  torso_d_rot_y_center  torso_d_rot_z_center
# count             1071.000000           1071.000000           1071.000000
# mean                12.651167              6.088515              7.440710
# std                  4.423767              2.510648              1.942997
# min                  3.800000              1.000000              0.600000
# 25%                 10.200000              4.200000              6.300000
# 50%                 11.300000              6.000000              7.400000
# 75%                 13.000000              7.700000              8.500000
# max                 33.900000             15.900000             14.500000
#
# [8 rows x 24 columns]

# %%
lap3 = pd.read_csv('data/saita_natTT_lap3.csv', delimiter=',')
lap3.describe()
# Out:
#        elapsed_time      distance     latitude    longitude     altitude  \
# count   1065.000000   1063.000000  1016.000000  1016.000000  1065.000000
# mean    2690.000000  31974.796802    36.972824   136.786728    56.821596
# std      307.583322   3625.512646     0.013739     0.004631    10.703633
# min     2158.000000  25599.000000    36.953465   136.774700    44.000000
# 25%     2424.000000  28961.000000    36.959063   136.783370    47.000000
# 50%     2690.000000  31899.000000    36.970837   136.787805    55.000000
# 75%     2956.000000  34992.000000    36.984713   136.790485    67.000000
# max     3222.000000  38462.000000    36.998158   136.793550    74.000000
#
#        l_r_balance        power      cadence        speed  heartrate  \
# count          0.0  1065.000000  1065.000000  1065.000000        0.0
# mean           NaN   326.777465    88.619718    12.084930        NaN
# std            NaN    86.464965    13.601988     2.226143        NaN
# min            NaN     0.000000     0.000000     5.820000        NaN
# 25%            NaN   304.000000    87.000000    11.140000        NaN
# 50%            NaN   339.000000    91.000000    12.680000        NaN
# 75%            NaN   374.000000    94.000000    13.220000        NaN
# max            NaN   532.000000   112.000000    17.320000        NaN
#
#                ...           leg_range_log_left  leg_range_log_right  \
# count          ...                          0.0                  0.0
# mean           ...                          NaN                  NaN
# std            ...                          NaN                  NaN
# min            ...                          NaN                  NaN
# 25%            ...                          NaN                  NaN
# 50%            ...                          NaN                  NaN
# 75%            ...                          NaN                  NaN
# max            ...                          NaN                  NaN
#
#        pedaling_delay_log_left  pedaling_delay_log_right  \
# count              1032.000000               1028.000000
# mean                 25.231880                 26.249027
# std                  11.665851                 12.781717
# min                   0.200000                  0.000000
# 25%                  17.250000                 17.375000
# 50%                  27.000000                 29.000000
# 75%                  33.400000                 35.500000
# max                  50.000000                 51.100000
#
#        waist_angle_log_center  waist_d_rot_y_center  waist_d_rot_z_center  \
# count             1065.000000           1065.000000           1065.000000
# mean                49.523005              7.115023              6.700094
# std                  3.092871              3.954594              1.922104
# min                 38.600000              1.300000              0.600000
# 25%                 48.100000              5.500000              5.600000
# 50%                 49.300000              6.500000              6.600000
# 75%                 50.300000              7.500000              7.500000
# max                 63.800000             31.700000             13.700000
#
#        torso_angle_log_center  torso_d_rot_y_center  torso_d_rot_z_center
# count             1065.000000           1065.000000           1065.000000
# mean                13.073615              6.640376              8.586291
# std                  4.659380              2.822533              2.312458
# min                  5.700000              1.300000              0.800000
# 25%                 10.300000              4.400000              7.300000
# 50%                 11.800000              6.700000              8.700000
# 75%                 13.800000              8.600000             10.000000
# max                 37.700000             16.100000             15.900000
#
# [8 rows x 24 columns]

# %%
# Take a look at a random sample of the data.
lap1.sample(10)

# Looks like we have many null values.
# Out:
#       elapsed_time  distance   latitude  longitude  altitude  l_r_balance  \
# 538            540    6163.0  36.960050  136.78331        72          NaN
# 42              44     438.0  36.989605  136.79042        56          NaN
# 1013          1015   11885.0  36.977535  136.79315        48          NaN
# 993            995   11616.0  36.975197  136.79220        49          NaN
# 207            209    2453.0  36.990585  136.78453        44          NaN
# 660            662    7720.0  36.956880  136.77727        45          NaN
# 763            765    8741.0  36.957615  136.78313        71          NaN
# 186            188    2191.0  36.992840  136.78378        45          NaN
# 787            789    8982.0  36.959103  136.78394        67          NaN
# 296            298    3599.0  36.981907  136.79135        46          NaN
#
#       power  cadence  speed  heartrate          ...           \
# 538   266.0     99.0  12.53        NaN          ...
# 42    288.0    100.0  12.63        NaN          ...
# 1013  291.0     93.0  13.58        NaN          ...
# 993   357.0     94.0  12.79        NaN          ...
# 207   311.0     92.0  12.45        NaN          ...
# 660   322.0     98.0  13.37        NaN          ...
# 763   314.0     95.0  10.66        NaN          ...
# 186   325.0     96.0  12.16        NaN          ...
# 787   357.0     85.0  11.09        NaN          ...
# 296   310.0     99.0  13.44        NaN          ...
#
#       leg_range_log_left  leg_range_log_right  pedaling_delay_log_left  \
# 538                  NaN                  NaN                     26.1
# 42                   NaN                  NaN                     29.3
# 1013                 NaN                  NaN                     23.5
# 993                  NaN                  NaN                     26.6
# 207                  NaN                  NaN                     38.6
# 660                  NaN                  NaN                     19.2
# 763                  NaN                  NaN                     30.6
# 186                  NaN                  NaN                     30.3
# 787                  NaN                  NaN                      6.8
# 296                  NaN                  NaN                     22.6
#
#       pedaling_delay_log_right  waist_angle_log_center  waist_d_rot_y_center  \
# 538                       45.6                    45.8                  10.3
# 42                        34.1                    45.3                   4.6
# 1013                      27.3                    45.7                   6.5
# 993                       27.0                    47.2                   8.9
# 207                       29.9                    46.4                   7.9
# 660                       37.3                    46.0                   6.1
# 763                       35.8                    48.7                   6.9
# 186                       26.0                    47.2                   7.4
# 787                       31.0                    48.6                   1.8
# 296                       37.3                    46.1                   6.0
#
#       waist_d_rot_z_center  torso_angle_log_center  torso_d_rot_y_center  \
# 538                    7.4                    10.8                  10.2
# 42                     4.7                    12.3                   4.5
# 1013                   5.4                    11.1                   2.5
# 993                    7.0                    11.6                   7.8
# 207                    4.3                     8.4                   6.6
# 660                    6.5                    10.0                   5.0
# 763                    7.5                    13.9                   3.2
# 186                    7.6                     9.5                   4.5
# 787                    6.5                    17.5                   9.3
# 296                    7.0                    10.3                   5.9
#
#       torso_d_rot_z_center
# 538                    7.4
# 42                     5.1
# 1013                   5.0
# 993                    7.1
# 207                    6.0
# 660                    5.3
# 763                    9.4
# 186                    7.3
# 787                    9.0
# 296                    6.2
#
# [10 rows x 24 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# How many null values do we have?
lap1.isnull().sum().nlargest(15).plot(kind="barh")

# %%
lap2.isnull().sum().nlargest(15).plot(kind="barh")

# %%
lap3.isnull().sum().nlargest(15).plot(kind="barh")

# %%
# Today for simplicity sake, I will drop the columns full of null values:
# But I really want to know why this column is full of NaNs.  Would love to see those metrics!
lap1.drop(['l_r_balance', 'heartrate', 'leg_range_log_left', 'leg_range_log_right'], axis=1, inplace=True)
lap2.drop(['l_r_balance', 'heartrate', 'leg_range_log_left', 'leg_range_log_right'], axis=1, inplace=True)
lap3.drop(['l_r_balance', 'heartrate', 'leg_range_log_left', 'leg_range_log_right'], axis=1, inplace=True)

# %%
# Next I will fill the remaining null values.
lap1.fillna(method='ffill', inplace=True)
lap2.fillna(method='ffill', inplace=True)
lap3.fillna(method='ffill', inplace=True)

# %%
# How is our cleaning working?
lap1.isnull().sum()
# Out:
# elapsed_time                0
# distance                    0
# latitude                    0
# longitude                   0
# altitude                    0
# power                       0
# cadence                     0
# speed                       0
# ankling_log_left            0
# ankling_log_right           0
# foot_range_log_left         0
# foot_range_log_right        0
# pedaling_delay_log_left     0
# pedaling_delay_log_right    0
# waist_angle_log_center      0
# waist_d_rot_y_center        0
# waist_d_rot_z_center        0
# torso_angle_log_center      0
# torso_d_rot_y_center        0
# torso_d_rot_z_center        0
# dtype: int64

# %%
lap2.isnull().sum()
# Out:
# elapsed_time                0
# distance                    0
# latitude                    0
# longitude                   0
# altitude                    0
# power                       0
# cadence                     0
# speed                       0
# ankling_log_left            0
# ankling_log_right           0
# foot_range_log_left         0
# foot_range_log_right        0
# pedaling_delay_log_left     0
# pedaling_delay_log_right    0
# waist_angle_log_center      0
# waist_d_rot_y_center        0
# waist_d_rot_z_center        0
# torso_angle_log_center      0
# torso_d_rot_y_center        0
# torso_d_rot_z_center        0
# dtype: int64

# %%
lap3.isnull().sum()
# Out:
# elapsed_time                0
# distance                    0
# latitude                    0
# longitude                   0
# altitude                    0
# power                       0
# cadence                     0
# speed                       0
# ankling_log_left            0
# ankling_log_right           0
# foot_range_log_left         0
# foot_range_log_right        0
# pedaling_delay_log_left     0
# pedaling_delay_log_right    0
# waist_angle_log_center      0
# waist_d_rot_y_center        0
# waist_d_rot_z_center        0
# torso_angle_log_center      0
# torso_d_rot_y_center        0
# torso_d_rot_z_center        0
# dtype: int64

# %%
# Use Elapsed Time as the index
lap1.set_index('elapsed_time', inplace=True)
lap2.set_index('elapsed_time', inplace=True)
lap3.set_index('elapsed_time', inplace=True)

# %% [markdown]
# ## Scatter plots to look at distribution:
# * For simplicity today, I'm intersted in Power, and how the other metrics potentially contribute to better Power.

# %%
# Numeric Columns that I want to keep for plots:
lap1_num = lap1.select_dtypes(exclude=['object', 'category'])

# %%
# Scatter Subplot of Numeric Columns
fig = plt.figure(figsize=(16,16))

#Make for loop that will plot Numeric Columns vs Power

for i, col in enumerate(lap1_num):
    fig.add_subplot(10,4, 1+i)
    plt.scatter(lap1_num[col], lap1['power'])
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Power')    

plt.tight_layout() #Prevents overlapping!

# %% [markdown]
# Let's do the same scatter plots for Lap 2 and Lap 3.

# %%
# Numeric Columns that I want to keep for plots:
lap2_num = lap2.select_dtypes(exclude=['object', 'category'])  

# Scatter Subplot of Numeric Columns
fig = plt.figure(figsize=(16,16))

#Make for loop that will plot Numeric Columns vs Power

for i, col in enumerate(lap2_num):
    fig.add_subplot(10,4, 1+i)
    plt.scatter(lap2_num[col], lap2['power'])
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Power')    

plt.tight_layout() #Prevents overlapping!

# %%
# Numeric Columns that I want to keep for plots:
lap3_num = lap3.select_dtypes(exclude=['object', 'category'])  

# Scatter Subplot of Numeric Columns
fig = plt.figure(figsize=(16,16))

#Make for loop that will plot Numeric Columns vs Power

for i, col in enumerate(lap3_num):
    fig.add_subplot(10,4, 1+i)
    plt.scatter(lap3_num[col], lap3['power'])
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Power')    

plt.tight_layout() #Prevents overlapping!

# %% [markdown]
# ## Histograms!

# %%
# Histogram Subplot of Numeric Columns for Lap 1:
fig = plt.figure(figsize=(16,16))

#Make for loop that will plot Numeric Columns

for i, col in enumerate(lap1_num):
    fig.add_subplot(10,4, 1+i)
    sns.distplot(lap1_num[col], bins=45, kde=False, norm_hist=False, color='b')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Count')    

plt.tight_layout() #Prevents overlapping!

# %%
# Histogram Subplot of Numeric Columns for Lap 2:
fig = plt.figure(figsize=(16,16))

#Make for loop that will plot Numeric Columns

for i, col in enumerate(lap2_num):
    fig.add_subplot(10,4, 1+i)
    sns.distplot(lap2_num[col], bins=100, kde=False, norm_hist=False, color='g')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Count')    

plt.tight_layout() #Prevents overlapping!

# %%
# Histogram Subplot of Numeric Columns for Lap 3:
fig = plt.figure(figsize=(16,16))

#Make for loop that will plot Numeric Columns

for i, col in enumerate(lap3_num):
    fig.add_subplot(10,4, 1+i)
    sns.distplot(lap3_num[col], bins=60, kde=False, norm_hist=False, color='r')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Count')    

plt.tight_layout() #Prevents overlapping!

# %% [markdown]
# Intersting observations so far:
# * The third lap was the fastest speed, with best mean power (326 watts) and lowest mean cadence (88 RPM).
# * On the third lap especially, the athlete seems to have some pedaling imbalances (ie: the Pedaling Delay Logs of Left vs. Right have greater differences).
# * Mean Waist Angle Log Center increases by 2 degrees over the 3 laps.  Maybe the handlebar position is too low and/or the athlete has too much pressure on the front of the saddle?
# * Mean Torso Angle also increases each lap.  This also supports revisiting the handlebar position and saddle choice.
# * Mean Torso Rotation increases nearly 2 degrees.  How is this athlete's core strength?

# %% [markdown]
# Pickle for next notebooks:

# %%
lap1.to_pickle('data/lap1.p')
lap2.to_pickle('data/lap2.p')
lap3.to_pickle('data/lap3.p')
